# %%
# STEP 0 — 建立分類器資料集（ROI crops，不分左右，統一方向）
from PIL import Image
import pandas as pd
from pathlib import Path

PROJ = Path(r"D:/中興大學/碩一上/仁愛醫院/仁愛醫院調整8總整理").resolve()  # ✅ 新專案根目錄
YOLO_ROOT = PROJ / "yolo_dataset_process"
IMG_ALL = YOLO_ROOT / "yolo_dataset" / "images"

df = pd.read_csv(PROJ/"roi_all.csv")  # 建議從 調整5 複製過來，或在6重跑一次生成

OUT = PROJ / "stage_cls_dataset"
OUT.mkdir(exist_ok=True, parents=True)
OUT_ROOT = Path(PROJ) / "outputs_bin(2),(3)"
# 統一成哪一邊的樣子？"L" = 全部變成左邊樣子；"R" = 全部變成右邊樣子
UNIFY_SIDE = "L"   # 老師說「都只有在左邊或右邊」，你可以先選 L

for _, r in df.iterrows():
    if pd.isna(r["x1"]):
        continue  # 沒偵測到跳過
    
    stage = int(r["stage"])
    side  = str(r["side"]).upper()  # 'L' 或 'R'
    
    out_dir = OUT / f"stage_{stage}"
    out_dir.mkdir(exist_ok=True, parents=True)
    
    img_path = IMG_ALL / r["filename"]
    x1, y1, x2, y2 = map(int, [r.x1, r.y1, r.x2, r.y2])
    
    with Image.open(img_path) as im:
        crop = im.crop((x1, y1, x2, y2))
        
        # 🔁 關鍵：把另一側翻成統一方向
        if UNIFY_SIDE == "L":
            # 希望所有關節都長得像「左側」 → 把右邊關節水平翻轉
            if side == "R":
                crop = crop.transpose(Image.FLIP_LEFT_RIGHT)
        elif UNIFY_SIDE == "R":
            # 希望都長得像「右側」 → 把左邊翻轉
            if side == "L":
                crop = crop.transpose(Image.FLIP_LEFT_RIGHT)
        else:
            raise ValueError("UNIFY_SIDE 只能是 'L' 或 'R'")
        
        crop.save(out_dir / r["filename"])

print("完成建立 stage_cls_dataset（已統一方向，不分左右）：", OUT)
# Out:
# 完成建立 stage_cls_dataset（已統一方向，不分左右）： D:\中興大學\碩一上\仁愛醫院\仁愛醫院調整8總整理\stage_cls_dataset

# %%
import torch
import numpy as np
import random
import os

def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)

    # 如果用 GPU
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)

    # 讓 cuDNN 的結果固定（禁用一些非確定性加速）
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(42)
print("Seed fixed!")
# Out:
# Seed fixed!

# %%
from torch.utils.data import Dataset

class BinaryStageWrapper(Dataset):
    """
    (2) vs (3) binary classifier
    label convention:
      y2=0 => stage_2
      y2=1 => stage_3
    We will ONLY keep samples from stage_2 and stage_3.
    """
    def __init__(self, base_dataset):
        self.base = base_dataset

        # base_dataset is ImageFolder -> base_dataset.samples: [(path, y), ...]
        # y: 0..3  (stage_1..stage_4)
        self.keep_indices = [i for i, (_, y) in enumerate(self.base.samples) if y in (1, 2)]  # stage2=1, stage3=2

    def __len__(self):
        return len(self.keep_indices)

    def __getitem__(self, idx):
        real_idx = self.keep_indices[idx]
        x, y4 = self.base[real_idx]  # y4: 0..3
        # stage2 -> 0, stage3 -> 1
        y2 = 0 if y4 == 1 else 1
        return x, y2

# %%
import torch
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader, Subset
import torchvision.transforms as T

DATA_ROOT = OUT

train_tf = T.Compose([
    T.Resize((384, 384)),
    T.RandomRotation(10),
    T.ToTensor(),
    T.Normalize([0.5]*3, [0.5]*3)
])

val_tf = T.Compose([
    T.Resize((384, 384)),
    T.ToTensor(),
    T.Normalize([0.5]*3, [0.5]*3)
])

# 先建 4-class dataset
train_dataset4 = ImageFolder(DATA_ROOT, transform=train_tf)
val_dataset4   = ImageFolder(DATA_ROOT, transform=val_tf)
test_dataset4  = ImageFolder(DATA_ROOT, transform=val_tf)

# 再用 wrapper 變成只含 stage2/3 的 binary dataset
train_dataset = BinaryStageWrapper(train_dataset4)
val_dataset   = BinaryStageWrapper(val_dataset4)
test_dataset  = BinaryStageWrapper(test_dataset4)

print("Binary dataset size:", len(train_dataset))

# ===== split ratio =====
train_ratio, val_ratio, test_ratio = 0.7, 0.15, 0.15
g = torch.Generator().manual_seed(42)

# wrapper 後的 labels2（0/1）
labels2 = torch.tensor([train_dataset[i][1] for i in range(len(train_dataset))])

train_idx_all, val_idx_all, test_idx_all = [], [], []
num_classes = 2

for c in range(num_classes):
    idx_c = torch.where(labels2 == c)[0]
    idx_c = idx_c[torch.randperm(len(idx_c), generator=g)]

    n = len(idx_c)
    n_train = int(n * train_ratio)
    n_val   = int(n * val_ratio)

    train_idx_all.append(idx_c[:n_train])
    val_idx_all.append(idx_c[n_train:n_train+n_val])
    test_idx_all.append(idx_c[n_train+n_val:])

train_idx = torch.cat(train_idx_all)
val_idx   = torch.cat(val_idx_all)
test_idx  = torch.cat(test_idx_all)

# shuffle
train_idx = train_idx[torch.randperm(len(train_idx), generator=g)]
val_idx   = val_idx[torch.randperm(len(val_idx), generator=g)]
test_idx  = test_idx[torch.randperm(len(test_idx), generator=g)]

print("train/val/test =", len(train_idx), len(val_idx), len(test_idx))

train_set = Subset(train_dataset, train_idx.tolist())
val_set   = Subset(val_dataset,   val_idx.tolist())
test_set  = Subset(test_dataset,  test_idx.tolist())

train_loader = DataLoader(train_set, batch_size=16, shuffle=True)
val_loader   = DataLoader(val_set,   batch_size=16, shuffle=False)
test_loader  = DataLoader(test_set,  batch_size=16, shuffle=False)

# check class counts
def count_per_class(idxs):
    c = torch.bincount(labels2[idxs], minlength=2)
    return c.tolist()

print("per-class train:", count_per_class(train_idx))
print("per-class val  :", count_per_class(val_idx))
print("per-class test :", count_per_class(test_idx))
# Out:
# Binary dataset size: 172
# train/val/test = 120 25 27
# per-class train: [78, 42]
# per-class val  : [16, 9]
# per-class test : [18, 9]

# %%
from pathlib import Path
import torch
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader, Subset

DATA_ROOT = OUT  # 你的 stage_cls_dataset
# base_dataset = ImageFolder(DATA_ROOT)  # 只用來拿 labels，不套 transform

# # ===== 你想要的比例 =====
# train_ratio = 0.7
# val_ratio   = 0.15
# test_ratio  = 0.15
# assert abs(train_ratio + val_ratio + test_ratio - 1.0) < 1e-8

# # 固定 random seed
# g = torch.Generator().manual_seed(42)

# # 取得每張圖的 label
# labels4 = torch.tensor([y for _, y in base_dataset.samples])  # 0..3
# labels2 = (labels4 >= 2).long()  # 0: (0,1)  1: (2,3)

# train_idx_all, val_idx_all, test_idx_all = [], [], []
# num_classes = 2

# for c in range(num_classes):
#     idx_c = torch.where(labels2 == c)[0]
#     idx_c = idx_c[torch.randperm(len(idx_c), generator=g)]

#     n_c = len(idx_c)
#     n_train_c = int(n_c * train_ratio)
#     n_val_c   = int(n_c * val_ratio)
#     n_test_c  = n_c - n_train_c - n_val_c

#     train_idx_all.append(idx_c[:n_train_c])
#     val_idx_all.append(idx_c[n_train_c:n_train_c + n_val_c])
#     test_idx_all.append(idx_c[n_train_c + n_val_c:])

# train_idx = torch.cat(train_idx_all)
# val_idx   = torch.cat(val_idx_all)
# test_idx  = torch.cat(test_idx_all)

# # 再打散一次（可選，但我通常會做）
# train_idx = train_idx[torch.randperm(len(train_idx), generator=g)]
# val_idx   = val_idx[torch.randperm(len(val_idx), generator=g)]
# test_idx  = test_idx[torch.randperm(len(test_idx), generator=g)]

# print("train/val/test =", len(train_idx), len(val_idx), len(test_idx))

# # ===== 各自有 transform 的 dataset =====
# train_dataset4 = ImageFolder(DATA_ROOT, transform=train_tf)
# val_dataset4   = ImageFolder(DATA_ROOT, transform=val_tf)
# test_dataset4  = ImageFolder(DATA_ROOT, transform=val_tf)

# train_dataset = BinaryStageWrapper(train_dataset4)
# val_dataset   = BinaryStageWrapper(val_dataset4)
# test_dataset  = BinaryStageWrapper(test_dataset4)


# train_set = Subset(train_dataset, train_idx.tolist())
# val_set   = Subset(val_dataset,   val_idx.tolist())
# test_set  = Subset(test_dataset,  test_idx.tolist())

# train_loader = DataLoader(train_set, batch_size=16, shuffle=True)
# val_loader   = DataLoader(val_set,   batch_size=16, shuffle=False)
# test_loader  = DataLoader(test_set,  batch_size=16, shuffle=False)

# # 額外：看每個 split 的 class 分布（強烈建議）
# def count_per_class(idxs):
#     c = torch.bincount(labels2[idxs], minlength=2)
#     return c.tolist()

# print("per-class train:", count_per_class(train_idx))
# print("per-class val  :", count_per_class(val_idx))
# print("per-class test :", count_per_class(test_idx))

# %%
# STEP 2 — 建立分類器模型（可切換不同 backbone）
import torchvision.models as models
import torch.nn as nn

device = "cuda" if torch.cuda.is_available() else "cpu"
print("device =", device)

def create_model(model_name: str, num_classes: int = 2):
    """依模型名稱建立對應的預訓練模型，最後一層改成 num_classes。"""
    model_name = model_name.lower()

    if model_name == "efficientnet_b0":
        weights = models.EfficientNet_B0_Weights.DEFAULT
        model = models.efficientnet_b0(weights=weights)
        in_features = model.classifier[1].in_features
        model.classifier[1] = nn.Linear(in_features, num_classes)

    elif model_name == "efficientnet_b1":
        weights = models.EfficientNet_B1_Weights.DEFAULT
        model = models.efficientnet_b1(weights=weights)
        in_features = model.classifier[1].in_features
        model.classifier[1] = nn.Linear(in_features, num_classes)

    elif model_name == "resnet50":
        weights = models.ResNet50_Weights.DEFAULT
        model = models.resnet50(weights=weights)
        in_features = model.fc.in_features
        model.fc = nn.Linear(in_features, num_classes)

    elif model_name == "convnext_tiny":
        weights = models.ConvNeXt_Tiny_Weights.DEFAULT
        model = models.convnext_tiny(weights=weights)
        in_features = model.classifier[2].in_features
        model.classifier[2] = nn.Linear(in_features, num_classes)

    elif model_name == "convnext_small":
        weights = models.ConvNeXt_Small_Weights.DEFAULT
        model = models.convnext_small(weights=weights)
        in_features = model.classifier[2].in_features
        model.classifier[2] = nn.Linear(in_features, num_classes)

    elif model_name == "convnext_base":
        weights = models.ConvNeXt_Base_Weights.DEFAULT
        model = models.convnext_base(weights=weights)
        in_features = model.classifier[2].in_features
        model.classifier[2] = nn.Linear(in_features, num_classes)

    elif model_name == "vit_b_16":
        weights = models.ViT_B_16_Weights.DEFAULT
        model = models.vit_b_16(weights=weights)
        in_features = model.heads.head.in_features
        model.heads.head = nn.Linear(in_features, num_classes)

    # 🔥 新增 DenseNet（醫療分類最常用）
    elif model_name == "densenet121":
        weights = models.DenseNet121_Weights.DEFAULT
        model = models.densenet121(weights=weights)
        in_features = model.classifier.in_features
        model.classifier = nn.Linear(in_features, num_classes)

    elif model_name == "densenet169":
        weights = models.DenseNet169_Weights.DEFAULT
        model = models.densenet169(weights=weights)
        in_features = model.classifier.in_features
        model.classifier = nn.Linear(in_features, num_classes)

    else:
        raise ValueError(f"未知的 model_name: {model_name}")

    return model

# 👉 在這裡選你要的 backbone
# model_name = "convnext_tiny"   # 改成 "efficientnet_b1" / "resnet50" / "convnext_tiny" / "vit_b_16"

# model = create_model(model_name, num_classes=4).to(device)
# print("使用模型:", model_name)
# Out:
# device = cuda

# %%
# STEP 3 — train_one_model（+ train_log.csv + training time）
import torch
import torch.optim as optim
import torch.nn.functional as F
from pathlib import Path
from sklearn.metrics import accuracy_score, f1_score
import time
import pandas as pd

def train_one_model(
    model_name,
    create_model_fn,
    train_loader,
    val_loader,
    device,
    PROJ,
    num_classes=2,
    epochs=30,
    lr=1e-4,
):
    out_dir = Path(PROJ) / "outputs_bin(2),(3)" / model_name
    out_dir.mkdir(parents=True, exist_ok=True)

    ckpt_path = out_dir / f"best_{model_name}.pth"
    log_path  = out_dir / "train_log.csv"

    model = create_model_fn(model_name, num_classes=num_classes).to(device)
    optimizer = optim.Adam(model.parameters(), lr=lr)

    # ✅ best 改成看 val_macro_f1
    best_val_macro_f1 = -1.0
    best_epoch = -1

    # 🔹 收集 epoch log
    logs = []

    t_start = time.time()

    for epoch in range(1, epochs + 1):
        model.train()
        total_loss = 0.0
        correct = 0
        total = 0

        for imgs, labels in train_loader:
            imgs = imgs.to(device)
            labels = labels.to(device)

            optimizer.zero_grad()
            logits = model(imgs)
            loss = F.cross_entropy(logits, labels)
            loss.backward()
            optimizer.step()

            total_loss += loss.item() * imgs.size(0)
            pred = logits.argmax(dim=1)
            correct += (pred == labels).sum().item()
            total += imgs.size(0)

        train_loss = total_loss / max(total, 1)
        train_acc  = correct / max(total, 1)

        # ---- validation ----
        model.eval()
        y_true, y_pred = [], []
        with torch.no_grad():
            for imgs, labels in val_loader:
                imgs = imgs.to(device)
                labels = labels.to(device)
                logits = model(imgs)
                pred = logits.argmax(dim=1)
                y_true.extend(labels.cpu().numpy())
                y_pred.extend(pred.cpu().numpy())

        val_acc = accuracy_score(y_true, y_pred)
        val_macro_f1 = f1_score(y_true, y_pred, average="macro")

        print(
            f"[{model_name}] Epoch {epoch:02d}/{epochs} | "
            f"loss={train_loss:.4f} acc={train_acc:.3f} "
            f"val_acc={val_acc:.3f} val_macro_f1={val_macro_f1:.3f}"
        )

        # 🔹 存 log（多存一欄 val_macro_f1）
        logs.append({
            "epoch": epoch,
            "train_loss": train_loss,
            "train_acc": train_acc,
            "val_acc": val_acc,
            "val_macro_f1": val_macro_f1,
        })

        # 🔥 best model（改用 val_macro_f1）
        if val_macro_f1 > best_val_macro_f1:
            best_val_macro_f1 = val_macro_f1
            best_epoch = epoch
            torch.save(model.state_dict(), ckpt_path)
            print(f"  👉 New best saved (epoch={epoch}, val_macro_f1={best_val_macro_f1:.3f})")

    t_end = time.time()
    train_time_sec = t_end - t_start

    # 🔹 儲存 train_log.csv
    df_log = pd.DataFrame(logs)
    df_log.to_csv(log_path, index=False, encoding="utf-8-sig")

    print(f"📄 saved train log -> {log_path}")
    print(f"⏱ training time = {train_time_sec:.1f} sec ({train_time_sec/60:.2f} min)")

    # load best model
    model.load_state_dict(torch.load(ckpt_path, map_location=device))
    model.eval()

    # ✅ 第二個回傳值現在是 best_val_macro_f1（位置不變）
    return model, best_val_macro_f1, best_epoch, ckpt_path, train_time_sec

# %%
# STEP 4 — eval + save：自動存 confusion matrix + report 到 outputs/{model_name}/
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
import torch
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, f1_score

def eval_and_save(model, loader, class_names, model_name, split_name, device, PROJ):
    out_dir = Path(PROJ) / "outputs_bin(2),(3)" / model_name
    out_dir.mkdir(parents=True, exist_ok=True)

    y_true, y_pred = [], []

    model.eval()
    with torch.no_grad():
        for imgs, labels in loader:
            imgs = imgs.to(device)
            labels = labels.to(device)
            logits = model(imgs)
            pred = logits.argmax(dim=1)
            y_true.extend(labels.cpu().numpy())
            y_pred.extend(pred.cpu().numpy())

    acc = accuracy_score(y_true, y_pred)
    macro_f1 = f1_score(y_true, y_pred, average="macro")
    weighted_f1 = f1_score(y_true, y_pred, average="weighted")

    cm = confusion_matrix(y_true, y_pred)

    # --- save confusion matrix figure ---
    fig, ax = plt.subplots(figsize=(5, 5))
    im = ax.imshow(cm, cmap="Blues")
    ax.set_xticks(np.arange(len(class_names)))
    ax.set_yticks(np.arange(len(class_names)))
    ax.set_xticklabels(class_names)
    ax.set_yticklabels(class_names)
    ax.set_xlabel("Predicted")
    ax.set_ylabel("True")
    ax.set_title(f"{model_name} | {split_name}")

    for i in range(len(class_names)):
        for j in range(len(class_names)):
            ax.text(
                j, i, cm[i, j],
                ha="center", va="center",
                color="white" if cm[i, j] > cm.max() / 2 else "black"
            )

    plt.colorbar(im, ax=ax)
    plt.tight_layout()

    cm_path = out_dir / f"confusion_matrix_{split_name}.png"
    plt.savefig(cm_path, dpi=300, bbox_inches="tight")
    plt.close()

    # --- save classification report ---
    report = classification_report(y_true, y_pred, target_names=class_names, digits=4)
    report_path = out_dir / f"classification_report_{split_name}.txt"
    report_path.write_text(report, encoding="utf-8")

    return {
        "acc": float(acc),
        "macro_f1": float(macro_f1),
        "weighted_f1": float(weighted_f1),
        "cm_path": str(cm_path),
        "report_path": str(report_path),
    }

# %%
# STEP 5 — 一鍵 train 所有模型 + 自動輸出 outputs/summary.csv + 自動挑 best 並複製到 outputs/_best_model
import pandas as pd
import torch
from pathlib import Path
import shutil

ALL_MODELS = [
    "efficientnet_b0",
    "efficientnet_b1",
    "resnet50",
    "convnext_tiny",
    "convnext_small",
    "densenet121",
    "densenet169",
    # "vit_b_16",
]

class_names = ["stage_2", "stage_3"]

summaries = []

for mn in ALL_MODELS:
    try:
        print("\n" + "="*100)
        print("TRAIN MODEL:", mn)

        # train_one_model 請確保回傳：
        # model, best_val_acc, best_epoch, ckpt_path, train_time_sec
        model, best_val_macro_f1, best_epoch, ckpt_path, train_time_sec = train_one_model(
            model_name=mn,
            create_model_fn=create_model,
            train_loader=train_loader,
            val_loader=val_loader,
            device=device,
            PROJ=PROJ,
            num_classes=2,
            epochs=30,
            lr=1e-4,
        )

        # eval + save val/test（請確保 eval_and_save 有回傳 acc/macro_f1/weighted_f1/cm_path/report_path）
        val_metrics  = eval_and_save(model, val_loader,  class_names, mn, "val",  device, PROJ)
        test_metrics = eval_and_save(model, test_loader, class_names, mn, "test", device, PROJ)

        summaries.append({
            "model_name": mn,
            "best_epoch": int(best_epoch),
            "best_ckpt": str(ckpt_path),
            "best_val_macro_f1_during_train": float(best_val_macro_f1),

            "train_time_sec": round(float(train_time_sec), 1),
            "train_time_min": round(float(train_time_sec) / 60, 2),

            "val_acc": float(val_metrics["acc"]),
            "val_macro_f1": float(val_metrics["macro_f1"]),
            "val_weighted_f1": float(val_metrics["weighted_f1"]),

            "test_acc": float(test_metrics["acc"]),
            "test_macro_f1": float(test_metrics["macro_f1"]),
            "test_weighted_f1": float(test_metrics["weighted_f1"]),

            "val_cm_path": str(val_metrics["cm_path"]),
            "test_cm_path": str(test_metrics["cm_path"]),
            "val_report_path": str(val_metrics.get("report_path", "")),
            "test_report_path": str(test_metrics.get("report_path", "")),
        })

        if torch.cuda.is_available():
            torch.cuda.empty_cache()

    except Exception as e:
        print(f"[!] Model {mn} failed:", repr(e))
        summaries.append({"model_name": mn, "error": repr(e)})

# ===== Summary DataFrame =====
df_summary = pd.DataFrame(summaries)

# 只挑沒有 error 的列來選 best
df_ok = df_summary.copy()
if "error" in df_ok.columns:
    df_ok = df_ok[df_ok["error"].isna()]

# ===== Select BEST model by val_macro_f1 =====

# 預設沒有 best
df_summary["is_best_val_macro_f1"] = False

best_model = None
best_row = None

# 只挑沒有 error 的列
df_ok = df_summary.copy()
if "error" in df_ok.columns:
    df_ok = df_ok[df_ok["error"].isna()]

if len(df_ok) == 0:
    print("[!] No successful models to select best from.")
else:
    if "val_macro_f1" not in df_ok.columns:
        print("[!] val_macro_f1 not found in summary, cannot select best.")
    else:
        # 👉 用 val_macro_f1 選最佳
        best_row = df_ok.sort_values(by="val_macro_f1", ascending=False).iloc[0]
        best_model = best_row["model_name"]

        # 標記 best
        df_summary["is_best_val_macro_f1"] = (
            df_summary["model_name"] == best_model
        )

        print(
            f"🏆 BEST model by val_macro_f1 = {best_model} "
            f"(val_macro_f1={best_row['val_macro_f1']:.4f})"
        )

# 排序（讓表格好看）
if "val_macro_f1" in df_summary.columns:
    df_summary = df_summary.sort_values(by="val_macro_f1", ascending=False)


# ===== 寫出 summary.csv =====
summary_path = OUT_ROOT / "summary.csv"
summary_path.parent.mkdir(parents=True, exist_ok=True)
df_summary.to_csv(summary_path, index=False, encoding="utf-8-sig")
print("\n✅ saved summary:", summary_path)

# ===== 複製 best model artifacts 到 outputs/_best_model =====
best_dir = OUT_ROOT / "_best_model"
best_dir.mkdir(parents=True, exist_ok=True)

if best_model is None:
    print("[!] Best model not selected, skip copying.")
else:
    # 清空舊 best_dir（可選）
    for p in best_dir.glob("*"):
        if p.is_file():
            p.unlink()
        elif p.is_dir():
            shutil.rmtree(p)

    src_dir = OUT_ROOT / best_model

    keep_files = [
        f"best_{best_model}.pth",
        "train_log.csv",
        "confusion_matrix_val.png",
        "confusion_matrix_test.png",
        "classification_report_val.txt",
        "classification_report_test.txt",
    ]

    for fn in keep_files:
        src = src_dir / fn
        if src.exists():
            shutil.copy2(src, best_dir / fn)

    # BEST_INFO.txt
    (best_dir / "BEST_INFO.txt").write_text(
        "Best model selected by val_macro_f1\n"
        f"model_name: {best_model}\n"
        f"val_macro_f1: {float(best_row['val_macro_f1']):.6f}\n"
        f"val_acc: {float(best_row.get('val_acc', float('nan'))):.6f}\n"
        f"test_macro_f1: {float(best_row.get('test_macro_f1', float('nan'))):.6f}\n"
        f"test_acc: {float(best_row.get('test_acc', float('nan'))):.6f}\n",
        encoding="utf-8"
    )

    print("✅ Copied best artifacts to:", best_dir)

df_summary
# Out:
# ====================================================================================================
# TRAIN MODEL: efficientnet_b0
# [efficientnet_b0] Epoch 01/30 | loss=0.6933 acc=0.517 val_acc=0.400 val_macro_f1=0.332
#   👉 New best saved (epoch=1, val_macro_f1=0.332)
# [efficientnet_b0] Epoch 02/30 | loss=0.6288 acc=0.633 val_acc=0.600 val_macro_f1=0.594
#   👉 New best saved (epoch=2, val_macro_f1=0.594)
# [efficientnet_b0] Epoch 03/30 | loss=0.5720 acc=0.733 val_acc=0.440 val_macro_f1=0.417
# [efficientnet_b0] Epoch 04/30 | loss=0.5267 acc=0.742 val_acc=0.560 val_macro_f1=0.533
# [efficientnet_b0] Epoch 05/30 | loss=0.5135 acc=0.717 val_acc=0.600 val_macro_f1=0.540
# [efficientnet_b0] Epoch 06/30 | loss=0.4452 acc=0.767 val_acc=0.600 val_macro_f1=0.504
# [efficientnet_b0] Epoch 07/30 | loss=0.4402 acc=0.800 val_acc=0.640 val_macro_f1=0.571
# [efficientnet_b0] Epoch 08/30 | loss=0.4078 acc=0.842 val_acc=0.680 val_macro_f1=0.561
# [efficientnet_b0] Epoch 09/30 | loss=0.3172 acc=0.917 val_acc=0.720 val_macro_f1=0.636
#   👉 New best saved (epoch=9, val_macro_f1=0.636)
# [efficientnet_b0] Epoch 10/30 | loss=0.2842 acc=0.933 val_acc=0.720 val_macro_f1=0.636
# [efficientnet_b0] Epoch 11/30 | loss=0.2415 acc=0.942 val_acc=0.720 val_macro_f1=0.636
# [efficientnet_b0] Epoch 12/30 | loss=0.2284 acc=0.933 val_acc=0.720 val_macro_f1=0.636
# [efficientnet_b0] Epoch 13/30 | loss=0.1968 acc=0.933 val_acc=0.760 val_macro_f1=0.702
#   👉 New best saved (epoch=13, val_macro_f1=0.702)
# [efficientnet_b0] Epoch 14/30 | loss=0.2057 acc=0.925 val_acc=0.760 val_macro_f1=0.702
# [efficientnet_b0] Epoch 15/30 | loss=0.1670 acc=0.967 val_acc=0.720 val_macro_f1=0.636
# [efficientnet_b0] Epoch 16/30 | loss=0.1410 acc=0.950 val_acc=0.760 val_macro_f1=0.702
# [efficientnet_b0] Epoch 17/30 | loss=0.1444 acc=0.958 val_acc=0.760 val_macro_f1=0.702
# [efficientnet_b0] Epoch 18/30 | loss=0.1185 acc=0.950 val_acc=0.760 val_macro_f1=0.702
# [efficientnet_b0] Epoch 19/30 | loss=0.1087 acc=0.958 val_acc=0.760 val_macro_f1=0.702
# [efficientnet_b0] Epoch 20/30 | loss=0.1151 acc=0.967 val_acc=0.760 val_macro_f1=0.702
# [efficientnet_b0] Epoch 21/30 | loss=0.0925 acc=0.975 val_acc=0.800 val_macro_f1=0.762
#   👉 New best saved (epoch=21, val_macro_f1=0.762)
# [efficientnet_b0] Epoch 22/30 | loss=0.1230 acc=0.958 val_acc=0.760 val_macro_f1=0.702
# [efficientnet_b0] Epoch 23/30 | loss=0.0801 acc=0.975 val_acc=0.800 val_macro_f1=0.777
#   👉 New best saved (epoch=23, val_macro_f1=0.777)
# [efficientnet_b0] Epoch 24/30 | loss=0.0896 acc=0.975 val_acc=0.800 val_macro_f1=0.788
#   👉 New best saved (epoch=24, val_macro_f1=0.788)
# [efficientnet_b0] Epoch 25/30 | loss=0.1386 acc=0.958 val_acc=0.800 val_macro_f1=0.762
# [efficientnet_b0] Epoch 26/30 | loss=0.1017 acc=0.967 val_acc=0.760 val_macro_f1=0.702
# [efficientnet_b0] Epoch 27/30 | loss=0.1132 acc=0.958 val_acc=0.800 val_macro_f1=0.762
# [efficientnet_b0] Epoch 28/30 | loss=0.0764 acc=0.967 val_acc=0.800 val_macro_f1=0.762
# [efficientnet_b0] Epoch 29/30 | loss=0.1137 acc=0.950 val_acc=0.800 val_macro_f1=0.762
# [efficientnet_b0] Epoch 30/30 | loss=0.0920 acc=0.967 val_acc=0.800 val_macro_f1=0.762
# 📄 saved train log -> D:\中興大學\碩一上\仁愛醫院\仁愛醫院調整8總整理\outputs_bin(2),(3)\efficientnet_b0\train_log.csv
# ⏱ training time = 27.6 sec (0.46 min)
#
# ====================================================================================================
# TRAIN MODEL: efficientnet_b1
# [efficientnet_b1] Epoch 01/30 | loss=0.6892 acc=0.500 val_acc=0.600 val_macro_f1=0.452
#   👉 New best saved (epoch=1, val_macro_f1=0.452)
# [efficientnet_b1] Epoch 02/30 | loss=0.6613 acc=0.658 val_acc=0.600 val_macro_f1=0.375
# [efficientnet_b1] Epoch 03/30 | loss=0.6513 acc=0.650 val_acc=0.640 val_macro_f1=0.390
# [efficientnet_b1] Epoch 04/30 | loss=0.6229 acc=0.650 val_acc=0.640 val_macro_f1=0.390
# [efficientnet_b1] Epoch 05/30 | loss=0.6094 acc=0.650 val_acc=0.640 val_macro_f1=0.390
# [efficientnet_b1] Epoch 06/30 | loss=0.6197 acc=0.658 val_acc=0.640 val_macro_f1=0.390
# [efficientnet_b1] Epoch 07/30 | loss=0.6046 acc=0.650 val_acc=0.640 val_macro_f1=0.390
# [efficientnet_b1] Epoch 08/30 | loss=0.6001 acc=0.683 val_acc=0.640 val_macro_f1=0.476
#   👉 New best saved (epoch=8, val_macro_f1=0.476)
# [efficientnet_b1] Epoch 09/30 | loss=0.5562 acc=0.742 val_acc=0.640 val_macro_f1=0.476
# [efficientnet_b1] Epoch 10/30 | loss=0.5465 acc=0.717 val_acc=0.640 val_macro_f1=0.476
# [efficientnet_b1] Epoch 11/30 | loss=0.5391 acc=0.717 val_acc=0.640 val_macro_f1=0.476
# [efficientnet_b1] Epoch 12/30 | loss=0.5290 acc=0.733 val_acc=0.640 val_macro_f1=0.476
# [efficientnet_b1] Epoch 13/30 | loss=0.4888 acc=0.767 val_acc=0.640 val_macro_f1=0.476
# [efficientnet_b1] Epoch 14/30 | loss=0.4701 acc=0.775 val_acc=0.640 val_macro_f1=0.476
# [efficientnet_b1] Epoch 15/30 | loss=0.4117 acc=0.825 val_acc=0.680 val_macro_f1=0.561
#   👉 New best saved (epoch=15, val_macro_f1=0.561)
# [efficientnet_b1] Epoch 16/30 | loss=0.3841 acc=0.817 val_acc=0.680 val_macro_f1=0.561
# [efficientnet_b1] Epoch 17/30 | loss=0.3512 acc=0.875 val_acc=0.760 val_macro_f1=0.724
#   👉 New best saved (epoch=17, val_macro_f1=0.724)
# [efficientnet_b1] Epoch 18/30 | loss=0.2976 acc=0.892 val_acc=0.720 val_macro_f1=0.667
# [efficientnet_b1] Epoch 19/30 | loss=0.2716 acc=0.917 val_acc=0.840 val_macro_f1=0.802
#   👉 New best saved (epoch=19, val_macro_f1=0.802)
# [efficientnet_b1] Epoch 20/30 | loss=0.2587 acc=0.900 val_acc=0.720 val_macro_f1=0.592
# [efficientnet_b1] Epoch 21/30 | loss=0.2428 acc=0.883 val_acc=0.880 val_macro_f1=0.857
#   👉 New best saved (epoch=21, val_macro_f1=0.857)
# [efficientnet_b1] Epoch 22/30 | loss=0.1855 acc=0.950 val_acc=0.840 val_macro_f1=0.816
# [efficientnet_b1] Epoch 23/30 | loss=0.2122 acc=0.950 val_acc=0.880 val_macro_f1=0.857
# [efficientnet_b1] Epoch 24/30 | loss=0.2139 acc=0.942 val_acc=0.880 val_macro_f1=0.857
# [efficientnet_b1] Epoch 25/30 | loss=0.1153 acc=0.958 val_acc=0.880 val_macro_f1=0.857
# [efficientnet_b1] Epoch 26/30 | loss=0.1274 acc=0.975 val_acc=0.880 val_macro_f1=0.866
#   👉 New best saved (epoch=26, val_macro_f1=0.866)
# [efficientnet_b1] Epoch 27/30 | loss=0.1589 acc=0.933 val_acc=0.880 val_macro_f1=0.866
# [efficientnet_b1] Epoch 28/30 | loss=0.1644 acc=0.933 val_acc=0.840 val_macro_f1=0.816
# [efficientnet_b1] Epoch 29/30 | loss=0.1801 acc=0.942 val_acc=0.880 val_macro_f1=0.857
# [efficientnet_b1] Epoch 30/30 | loss=0.1323 acc=0.967 val_acc=0.880 val_macro_f1=0.857
# 📄 saved train log -> D:\中興大學\碩一上\仁愛醫院\仁愛醫院調整8總整理\outputs_bin(2),(3)\efficientnet_b1\train_log.csv
# ⏱ training time = 46.9 sec (0.78 min)
#
# ====================================================================================================
# TRAIN MODEL: resnet50
# [resnet50] Epoch 01/30 | loss=0.6811 acc=0.533 val_acc=0.640 val_macro_f1=0.390
#   👉 New best saved (epoch=1, val_macro_f1=0.390)
# [resnet50] Epoch 02/30 | loss=0.6193 acc=0.658 val_acc=0.360 val_macro_f1=0.359
# [resnet50] Epoch 03/30 | loss=0.5944 acc=0.692 val_acc=0.360 val_macro_f1=0.265
# [resnet50] Epoch 04/30 | loss=0.5724 acc=0.683 val_acc=0.400 val_macro_f1=0.332
# [resnet50] Epoch 05/30 | loss=0.5273 acc=0.750 val_acc=0.480 val_macro_f1=0.477
#   👉 New best saved (epoch=5, val_macro_f1=0.477)
# [resnet50] Epoch 06/30 | loss=0.4567 acc=0.750 val_acc=0.640 val_macro_f1=0.618
#   👉 New best saved (epoch=6, val_macro_f1=0.618)
# [resnet50] Epoch 07/30 | loss=0.3780 acc=0.858 val_acc=0.640 val_macro_f1=0.618
# [resnet50] Epoch 08/30 | loss=0.2758 acc=0.917 val_acc=0.600 val_macro_f1=0.540
# [resnet50] Epoch 09/30 | loss=0.2241 acc=0.958 val_acc=0.760 val_macro_f1=0.702
#   👉 New best saved (epoch=9, val_macro_f1=0.702)
# [resnet50] Epoch 10/30 | loss=0.1609 acc=0.967 val_acc=0.760 val_macro_f1=0.702
# [resnet50] Epoch 11/30 | loss=0.1340 acc=0.958 val_acc=0.800 val_macro_f1=0.740
#   👉 New best saved (epoch=11, val_macro_f1=0.740)
# [resnet50] Epoch 12/30 | loss=0.1109 acc=0.967 val_acc=0.800 val_macro_f1=0.762
#   👉 New best saved (epoch=12, val_macro_f1=0.762)
# [resnet50] Epoch 13/30 | loss=0.1139 acc=0.958 val_acc=0.760 val_macro_f1=0.724
# [resnet50] Epoch 14/30 | loss=0.1085 acc=0.950 val_acc=0.800 val_macro_f1=0.777
#   👉 New best saved (epoch=14, val_macro_f1=0.777)
# [resnet50] Epoch 15/30 | loss=0.1509 acc=0.917 val_acc=0.800 val_macro_f1=0.740
# [resnet50] Epoch 16/30 | loss=0.0968 acc=0.975 val_acc=0.760 val_macro_f1=0.702
# [resnet50] Epoch 17/30 | loss=0.1483 acc=0.908 val_acc=0.800 val_macro_f1=0.799
#   👉 New best saved (epoch=17, val_macro_f1=0.799)
# [resnet50] Epoch 18/30 | loss=0.1152 acc=0.967 val_acc=0.720 val_macro_f1=0.713
# [resnet50] Epoch 19/30 | loss=0.0944 acc=0.967 val_acc=0.760 val_macro_f1=0.724
# [resnet50] Epoch 20/30 | loss=0.0840 acc=0.967 val_acc=0.800 val_macro_f1=0.762
# [resnet50] Epoch 21/30 | loss=0.0600 acc=0.967 val_acc=0.680 val_macro_f1=0.603
# [resnet50] Epoch 22/30 | loss=0.0586 acc=0.967 val_acc=0.800 val_macro_f1=0.762
# [resnet50] Epoch 23/30 | loss=0.0834 acc=0.958 val_acc=0.800 val_macro_f1=0.762
# [resnet50] Epoch 24/30 | loss=0.0671 acc=0.975 val_acc=0.760 val_macro_f1=0.724
# [resnet50] Epoch 25/30 | loss=0.0488 acc=0.975 val_acc=0.760 val_macro_f1=0.724
# [resnet50] Epoch 26/30 | loss=0.0484 acc=0.975 val_acc=0.760 val_macro_f1=0.724
# [resnet50] Epoch 27/30 | loss=0.0659 acc=0.967 val_acc=0.720 val_macro_f1=0.688
# [resnet50] Epoch 28/30 | loss=0.0631 acc=0.958 val_acc=0.800 val_macro_f1=0.777
# [resnet50] Epoch 29/30 | loss=0.0666 acc=0.950 val_acc=0.760 val_macro_f1=0.724
# [resnet50] Epoch 30/30 | loss=0.0582 acc=0.942 val_acc=0.800 val_macro_f1=0.762
# 📄 saved train log -> D:\中興大學\碩一上\仁愛醫院\仁愛醫院調整8總整理\outputs_bin(2),(3)\resnet50\train_log.csv
# ⏱ training time = 58.3 sec (0.97 min)
#
# ====================================================================================================
# TRAIN MODEL: convnext_tiny
# [convnext_tiny] Epoch 01/30 | loss=0.6779 acc=0.633 val_acc=0.640 val_macro_f1=0.390
#   👉 New best saved (epoch=1, val_macro_f1=0.390)
# [convnext_tiny] Epoch 02/30 | loss=0.6524 acc=0.650 val_acc=0.640 val_macro_f1=0.390
# [convnext_tiny] Epoch 03/30 | loss=0.6439 acc=0.650 val_acc=0.640 val_macro_f1=0.390
# [convnext_tiny] Epoch 04/30 | loss=0.6482 acc=0.650 val_acc=0.640 val_macro_f1=0.390
# [convnext_tiny] Epoch 05/30 | loss=0.6615 acc=0.617 val_acc=0.640 val_macro_f1=0.390
# [convnext_tiny] Epoch 06/30 | loss=0.6419 acc=0.650 val_acc=0.640 val_macro_f1=0.390
# [convnext_tiny] Epoch 07/30 | loss=0.6405 acc=0.650 val_acc=0.640 val_macro_f1=0.390
# [convnext_tiny] Epoch 08/30 | loss=0.6470 acc=0.650 val_acc=0.600 val_macro_f1=0.375
# [convnext_tiny] Epoch 09/30 | loss=0.6356 acc=0.658 val_acc=0.600 val_macro_f1=0.452
#   👉 New best saved (epoch=9, val_macro_f1=0.452)
# [convnext_tiny] Epoch 10/30 | loss=0.6084 acc=0.675 val_acc=0.600 val_macro_f1=0.452
# [convnext_tiny] Epoch 11/30 | loss=0.6455 acc=0.658 val_acc=0.640 val_macro_f1=0.390
# [convnext_tiny] Epoch 12/30 | loss=0.6166 acc=0.658 val_acc=0.640 val_macro_f1=0.390
# [convnext_tiny] Epoch 13/30 | loss=0.6052 acc=0.642 val_acc=0.600 val_macro_f1=0.375
# [convnext_tiny] Epoch 14/30 | loss=0.5568 acc=0.667 val_acc=0.640 val_macro_f1=0.532
#   👉 New best saved (epoch=14, val_macro_f1=0.532)
# [convnext_tiny] Epoch 15/30 | loss=0.6419 acc=0.667 val_acc=0.440 val_macro_f1=0.392
# [convnext_tiny] Epoch 16/30 | loss=0.5902 acc=0.717 val_acc=0.640 val_macro_f1=0.390
# [convnext_tiny] Epoch 17/30 | loss=0.4935 acc=0.742 val_acc=0.720 val_macro_f1=0.667
#   👉 New best saved (epoch=17, val_macro_f1=0.667)
# [convnext_tiny] Epoch 18/30 | loss=0.3106 acc=0.892 val_acc=0.640 val_macro_f1=0.476
# [convnext_tiny] Epoch 19/30 | loss=0.2769 acc=0.875 val_acc=0.840 val_macro_f1=0.802
#   👉 New best saved (epoch=19, val_macro_f1=0.802)
# [convnext_tiny] Epoch 20/30 | loss=0.2175 acc=0.917 val_acc=0.840 val_macro_f1=0.816
#   👉 New best saved (epoch=20, val_macro_f1=0.816)
# [convnext_tiny] Epoch 21/30 | loss=0.1392 acc=0.950 val_acc=0.840 val_macro_f1=0.816
# [convnext_tiny] Epoch 22/30 | loss=0.1384 acc=0.950 val_acc=0.800 val_macro_f1=0.799
# [convnext_tiny] Epoch 23/30 | loss=0.1017 acc=0.967 val_acc=0.720 val_macro_f1=0.636
# [convnext_tiny] Epoch 24/30 | loss=0.0995 acc=0.942 val_acc=0.800 val_macro_f1=0.777
# [convnext_tiny] Epoch 25/30 | loss=0.0891 acc=0.942 val_acc=0.840 val_macro_f1=0.826
#   👉 New best saved (epoch=25, val_macro_f1=0.826)
# [convnext_tiny] Epoch 26/30 | loss=0.0972 acc=0.950 val_acc=0.880 val_macro_f1=0.857
#   👉 New best saved (epoch=26, val_macro_f1=0.857)
# [convnext_tiny] Epoch 27/30 | loss=0.1222 acc=0.925 val_acc=0.840 val_macro_f1=0.838
# [convnext_tiny] Epoch 28/30 | loss=0.0603 acc=0.958 val_acc=0.800 val_macro_f1=0.777
# [convnext_tiny] Epoch 29/30 | loss=0.0752 acc=0.950 val_acc=0.840 val_macro_f1=0.816
# [convnext_tiny] Epoch 30/30 | loss=0.0913 acc=0.967 val_acc=0.840 val_macro_f1=0.833
# 📄 saved train log -> D:\中興大學\碩一上\仁愛醫院\仁愛醫院調整8總整理\outputs_bin(2),(3)\convnext_tiny\train_log.csv
# ⏱ training time = 99.7 sec (1.66 min)
#
# ====================================================================================================
# TRAIN MODEL: convnext_small
# [convnext_small] Epoch 01/30 | loss=0.8022 acc=0.567 val_acc=0.640 val_macro_f1=0.390
#   👉 New best saved (epoch=1, val_macro_f1=0.390)
# [convnext_small] Epoch 02/30 | loss=0.6986 acc=0.625 val_acc=0.640 val_macro_f1=0.390
# [convnext_small] Epoch 03/30 | loss=0.6885 acc=0.617 val_acc=0.640 val_macro_f1=0.390
# [convnext_small] Epoch 04/30 | loss=0.6742 acc=0.642 val_acc=0.640 val_macro_f1=0.390
# [convnext_small] Epoch 05/30 | loss=0.6927 acc=0.558 val_acc=0.640 val_macro_f1=0.390
# [convnext_small] Epoch 06/30 | loss=0.6421 acc=0.650 val_acc=0.640 val_macro_f1=0.390
# [convnext_small] Epoch 07/30 | loss=0.6686 acc=0.650 val_acc=0.640 val_macro_f1=0.390
# [convnext_small] Epoch 08/30 | loss=0.6483 acc=0.633 val_acc=0.640 val_macro_f1=0.390
# [convnext_small] Epoch 09/30 | loss=0.6578 acc=0.617 val_acc=0.640 val_macro_f1=0.390
# [convnext_small] Epoch 10/30 | loss=0.6883 acc=0.575 val_acc=0.600 val_macro_f1=0.375
# [convnext_small] Epoch 11/30 | loss=0.6741 acc=0.667 val_acc=0.640 val_macro_f1=0.390
# [convnext_small] Epoch 12/30 | loss=0.6367 acc=0.642 val_acc=0.640 val_macro_f1=0.390
# [convnext_small] Epoch 13/30 | loss=0.6634 acc=0.625 val_acc=0.640 val_macro_f1=0.390
# [convnext_small] Epoch 14/30 | loss=0.6572 acc=0.650 val_acc=0.640 val_macro_f1=0.390
# [convnext_small] Epoch 15/30 | loss=0.6517 acc=0.650 val_acc=0.640 val_macro_f1=0.390
# [convnext_small] Epoch 16/30 | loss=0.6667 acc=0.650 val_acc=0.640 val_macro_f1=0.390
# [convnext_small] Epoch 17/30 | loss=0.6487 acc=0.650 val_acc=0.640 val_macro_f1=0.390
# [convnext_small] Epoch 18/30 | loss=0.6511 acc=0.633 val_acc=0.640 val_macro_f1=0.390
# [convnext_small] Epoch 19/30 | loss=0.6490 acc=0.633 val_acc=0.640 val_macro_f1=0.390
# [convnext_small] Epoch 20/30 | loss=0.6709 acc=0.625 val_acc=0.640 val_macro_f1=0.532
#   👉 New best saved (epoch=20, val_macro_f1=0.532)
# [convnext_small] Epoch 21/30 | loss=0.6334 acc=0.625 val_acc=0.600 val_macro_f1=0.375
# [convnext_small] Epoch 22/30 | loss=0.6357 acc=0.650 val_acc=0.640 val_macro_f1=0.390
# [convnext_small] Epoch 23/30 | loss=0.6460 acc=0.642 val_acc=0.640 val_macro_f1=0.390
# [convnext_small] Epoch 24/30 | loss=0.6386 acc=0.642 val_acc=0.640 val_macro_f1=0.476
# [convnext_small] Epoch 25/30 | loss=0.6389 acc=0.642 val_acc=0.600 val_macro_f1=0.375
# [convnext_small] Epoch 26/30 | loss=0.6277 acc=0.675 val_acc=0.640 val_macro_f1=0.532
# [convnext_small] Epoch 27/30 | loss=0.6387 acc=0.667 val_acc=0.600 val_macro_f1=0.375
# [convnext_small] Epoch 28/30 | loss=0.6363 acc=0.625 val_acc=0.600 val_macro_f1=0.375
# [convnext_small] Epoch 29/30 | loss=0.6046 acc=0.658 val_acc=0.680 val_macro_f1=0.561
#   👉 New best saved (epoch=29, val_macro_f1=0.561)
# [convnext_small] Epoch 30/30 | loss=0.6161 acc=0.700 val_acc=0.600 val_macro_f1=0.375
# 📄 saved train log -> D:\中興大學\碩一上\仁愛醫院\仁愛醫院調整8總整理\outputs_bin(2),(3)\convnext_small\train_log.csv
# ⏱ training time = 1600.8 sec (26.68 min)
#
# ====================================================================================================
# TRAIN MODEL: densenet121
# [densenet121] Epoch 01/30 | loss=0.6597 acc=0.583 val_acc=0.360 val_macro_f1=0.359
#   👉 New best saved (epoch=1, val_macro_f1=0.359)
# [densenet121] Epoch 02/30 | loss=0.5499 acc=0.717 val_acc=0.520 val_macro_f1=0.500
#   👉 New best saved (epoch=2, val_macro_f1=0.500)
# [densenet121] Epoch 03/30 | loss=0.4728 acc=0.800 val_acc=0.600 val_macro_f1=0.594
#   👉 New best saved (epoch=3, val_macro_f1=0.594)
# [densenet121] Epoch 04/30 | loss=0.3834 acc=0.883 val_acc=0.640 val_macro_f1=0.638
#   👉 New best saved (epoch=4, val_macro_f1=0.638)
# [densenet121] Epoch 05/30 | loss=0.3029 acc=0.900 val_acc=0.760 val_macro_f1=0.750
#   👉 New best saved (epoch=5, val_macro_f1=0.750)
# [densenet121] Epoch 06/30 | loss=0.2055 acc=0.958 val_acc=0.840 val_macro_f1=0.816
#   👉 New best saved (epoch=6, val_macro_f1=0.816)
# [densenet121] Epoch 07/30 | loss=0.2077 acc=0.925 val_acc=0.800 val_macro_f1=0.740
# [densenet121] Epoch 08/30 | loss=0.2012 acc=0.908 val_acc=0.800 val_macro_f1=0.762
# [densenet121] Epoch 09/30 | loss=0.1171 acc=0.958 val_acc=0.680 val_macro_f1=0.561
# [densenet121] Epoch 10/30 | loss=0.1660 acc=0.958 val_acc=0.760 val_macro_f1=0.702
# [densenet121] Epoch 11/30 | loss=0.1237 acc=0.958 val_acc=0.840 val_macro_f1=0.816
# [densenet121] Epoch 12/30 | loss=0.1308 acc=0.950 val_acc=0.840 val_macro_f1=0.816
# [densenet121] Epoch 13/30 | loss=0.1018 acc=0.967 val_acc=0.840 val_macro_f1=0.816
# [densenet121] Epoch 14/30 | loss=0.0831 acc=0.958 val_acc=0.840 val_macro_f1=0.826
#   👉 New best saved (epoch=14, val_macro_f1=0.826)
# [densenet121] Epoch 15/30 | loss=0.0649 acc=0.967 val_acc=0.920 val_macro_f1=0.917
#   👉 New best saved (epoch=15, val_macro_f1=0.917)
# [densenet121] Epoch 16/30 | loss=0.0977 acc=0.950 val_acc=0.840 val_macro_f1=0.816
# [densenet121] Epoch 17/30 | loss=0.0888 acc=0.958 val_acc=0.840 val_macro_f1=0.816
# [densenet121] Epoch 18/30 | loss=0.0773 acc=0.958 val_acc=0.840 val_macro_f1=0.816
# [densenet121] Epoch 19/30 | loss=0.0687 acc=0.950 val_acc=0.800 val_macro_f1=0.762
# [densenet121] Epoch 20/30 | loss=0.1006 acc=0.942 val_acc=0.800 val_macro_f1=0.762
# [densenet121] Epoch 21/30 | loss=0.0648 acc=0.967 val_acc=0.800 val_macro_f1=0.762
# [densenet121] Epoch 22/30 | loss=0.0635 acc=0.967 val_acc=0.840 val_macro_f1=0.816
# [densenet121] Epoch 23/30 | loss=0.0753 acc=0.958 val_acc=0.840 val_macro_f1=0.816
# [densenet121] Epoch 24/30 | loss=0.0642 acc=0.958 val_acc=0.840 val_macro_f1=0.816
# [densenet121] Epoch 25/30 | loss=0.0630 acc=0.975 val_acc=0.840 val_macro_f1=0.816
# [densenet121] Epoch 26/30 | loss=0.0731 acc=0.950 val_acc=0.800 val_macro_f1=0.762
# [densenet121] Epoch 27/30 | loss=0.0616 acc=0.983 val_acc=0.880 val_macro_f1=0.857
# [densenet121] Epoch 28/30 | loss=0.0709 acc=0.975 val_acc=0.880 val_macro_f1=0.866
# [densenet121] Epoch 29/30 | loss=0.0830 acc=0.950 val_acc=0.800 val_macro_f1=0.762
# [densenet121] Epoch 30/30 | loss=0.0599 acc=0.967 val_acc=0.840 val_macro_f1=0.802
# 📄 saved train log -> D:\中興大學\碩一上\仁愛醫院\仁愛醫院調整8總整理\outputs_bin(2),(3)\densenet121\train_log.csv
# ⏱ training time = 44.2 sec (0.74 min)
#
# ====================================================================================================
# TRAIN MODEL: densenet169
# [densenet169] Epoch 01/30 | loss=0.6945 acc=0.500 val_acc=0.640 val_macro_f1=0.390
#   👉 New best saved (epoch=1, val_macro_f1=0.390)
# [densenet169] Epoch 02/30 | loss=0.5275 acc=0.758 val_acc=0.640 val_macro_f1=0.390
# [densenet169] Epoch 03/30 | loss=0.4412 acc=0.792 val_acc=0.640 val_macro_f1=0.390
# [densenet169] Epoch 04/30 | loss=0.3438 acc=0.892 val_acc=0.720 val_macro_f1=0.636
#   👉 New best saved (epoch=4, val_macro_f1=0.636)
# [densenet169] Epoch 05/30 | loss=0.2601 acc=0.908 val_acc=0.640 val_macro_f1=0.476
# [densenet169] Epoch 06/30 | loss=0.1766 acc=0.950 val_acc=0.720 val_macro_f1=0.667
#   👉 New best saved (epoch=6, val_macro_f1=0.667)
# [densenet169] Epoch 07/30 | loss=0.1622 acc=0.925 val_acc=0.800 val_macro_f1=0.777
#   👉 New best saved (epoch=7, val_macro_f1=0.777)
# [densenet169] Epoch 08/30 | loss=0.1113 acc=0.958 val_acc=0.720 val_macro_f1=0.667
# [densenet169] Epoch 09/30 | loss=0.1212 acc=0.958 val_acc=0.880 val_macro_f1=0.857
#   👉 New best saved (epoch=9, val_macro_f1=0.857)
# [densenet169] Epoch 10/30 | loss=0.1239 acc=0.967 val_acc=0.680 val_macro_f1=0.561
# [densenet169] Epoch 11/30 | loss=0.0959 acc=0.975 val_acc=0.640 val_macro_f1=0.476
# [densenet169] Epoch 12/30 | loss=0.1533 acc=0.942 val_acc=0.880 val_macro_f1=0.857
# [densenet169] Epoch 13/30 | loss=0.0941 acc=0.958 val_acc=0.840 val_macro_f1=0.816
# [densenet169] Epoch 14/30 | loss=0.1039 acc=0.942 val_acc=0.880 val_macro_f1=0.866
#   👉 New best saved (epoch=14, val_macro_f1=0.866)
# [densenet169] Epoch 15/30 | loss=0.0906 acc=0.958 val_acc=0.880 val_macro_f1=0.857
# [densenet169] Epoch 16/30 | loss=0.1073 acc=0.950 val_acc=0.880 val_macro_f1=0.866
# [densenet169] Epoch 17/30 | loss=0.1201 acc=0.950 val_acc=0.880 val_macro_f1=0.866
# [densenet169] Epoch 18/30 | loss=0.0736 acc=0.950 val_acc=0.800 val_macro_f1=0.762
# [densenet169] Epoch 19/30 | loss=0.0530 acc=0.975 val_acc=0.840 val_macro_f1=0.816
# [densenet169] Epoch 20/30 | loss=0.0613 acc=0.958 val_acc=0.800 val_macro_f1=0.777
# [densenet169] Epoch 21/30 | loss=0.0609 acc=0.983 val_acc=0.800 val_macro_f1=0.777
# [densenet169] Epoch 22/30 | loss=0.1200 acc=0.950 val_acc=0.840 val_macro_f1=0.816
# [densenet169] Epoch 23/30 | loss=0.0846 acc=0.967 val_acc=0.800 val_macro_f1=0.762
# [densenet169] Epoch 24/30 | loss=0.0680 acc=0.958 val_acc=0.800 val_macro_f1=0.762
# [densenet169] Epoch 25/30 | loss=0.0584 acc=0.967 val_acc=0.800 val_macro_f1=0.762
# [densenet169] Epoch 26/30 | loss=0.0585 acc=0.958 val_acc=0.800 val_macro_f1=0.762
# [densenet169] Epoch 27/30 | loss=0.0608 acc=0.942 val_acc=0.800 val_macro_f1=0.762
# [densenet169] Epoch 28/30 | loss=0.0577 acc=0.950 val_acc=0.800 val_macro_f1=0.762
# [densenet169] Epoch 29/30 | loss=0.0529 acc=0.975 val_acc=0.840 val_macro_f1=0.816
# [densenet169] Epoch 30/30 | loss=0.0548 acc=0.975 val_acc=0.840 val_macro_f1=0.816
# 📄 saved train log -> D:\中興大學\碩一上\仁愛醫院\仁愛醫院調整8總整理\outputs_bin(2),(3)\densenet169\train_log.csv
# ⏱ training time = 49.8 sec (0.83 min)
# 🏆 BEST model by val_macro_f1 = densenet121 (val_macro_f1=0.9167)
#
# ✅ saved summary: D:\中興大學\碩一上\仁愛醫院\仁愛醫院調整8總整理\outputs_bin(2),(3)\summary.csv
# ✅ Copied best artifacts to: D:\中興大學\碩一上\仁愛醫院\仁愛醫院調整8總整理\outputs_bin(2),(3)\_best_model
#         model_name  best_epoch  \
# 5      densenet121          15
# 6      densenet169          14
# 1  efficientnet_b1          26
# 3    convnext_tiny          26
# 2         resnet50          17
# 0  efficientnet_b0          24
# 4   convnext_small          29
#
#                                            best_ckpt  \
# 5  D:\中興大學\碩一上\仁愛醫院\仁愛醫院調整8總整理\outputs_bin(2),(3)...
# 6  D:\中興大學\碩一上\仁愛醫院\仁愛醫院調整8總整理\outputs_bin(2),(3)...
# 1  D:\中興大學\碩一上\仁愛醫院\仁愛醫院調整8總整理\outputs_bin(2),(3)...
# 3  D:\中興大學\碩一上\仁愛醫院\仁愛醫院調整8總整理\outputs_bin(2),(3)...
# 2  D:\中興大學\碩一上\仁愛醫院\仁愛醫院調整8總整理\outputs_bin(2),(3)...
# 0  D:\中興大學\碩一上\仁愛醫院\仁愛醫院調整8總整理\outputs_bin(2),(3)...
# 4  D:\中興大學\碩一上\仁愛醫院\仁愛醫院調整8總整理\outputs_bin(2),(3)...
#
#    best_val_macro_f1_during_train  train_time_sec  train_time_min  val_acc  \
# 5                        0.916667            44.2            0.74     0.92
# 6                        0.866310            49.8            0.83     0.88
# 1                        0.866310            46.9            0.78     0.88
# 3                        0.857143            99.7            1.66     0.88
# 2                        0.798712            58.3            0.97     0.80
# 0                        0.787776            27.6            0.46     0.80
# 4                        0.561404          1600.8           26.68     0.68
#
#    val_macro_f1  val_weighted_f1  test_acc  test_macro_f1  test_weighted_f1  \
# 5      0.916667         0.921333  0.888889       0.878195          0.890226
# 6      0.866310         0.878289  0.888889       0.878195          0.890226
# 1      0.866310         0.878289  0.888889       0.878195          0.890226
# 3      0.857143         0.873143  0.851852       0.807143          0.838095
# 2      0.798712         0.803221  0.703704       0.693182          0.712121
# 0      0.787776         0.802037  0.888889       0.878195          0.890226
# 4      0.561404         0.625263  0.629630       0.517857          0.595238
#
#                                          val_cm_path  \
# 5  D:\中興大學\碩一上\仁愛醫院\仁愛醫院調整8總整理\outputs_bin(2),(3)...
# 6  D:\中興大學\碩一上\仁愛醫院\仁愛醫院調整8總整理\outputs_bin(2),(3)...
# 1  D:\中興大學\碩一上\仁愛醫院\仁愛醫院調整8總整理\outputs_bin(2),(3)...
# 3  D:\中興大學\碩一上\仁愛醫院\仁愛醫院調整8總整理\outputs_bin(2),(3)...
# 2  D:\中興大學\碩一上\仁愛醫院\仁愛醫院調整8總整理\outputs_bin(2),(3)...
# 0  D:\中興大學\碩一上\仁愛醫院\仁愛醫院調整8總整理\outputs_bin(2),(3)...
# 4  D:\中興大學\碩一上\仁愛醫院\仁愛醫院調整8總整理\outputs_bin(2),(3)...
#
#                                         test_cm_path  \
# 5  D:\中興大學\碩一上\仁愛醫院\仁愛醫院調整8總整理\outputs_bin(2),(3)...
# 6  D:\中興大學\碩一上\仁愛醫院\仁愛醫院調整8總整理\outputs_bin(2),(3)...
# 1  D:\中興大學\碩一上\仁愛醫院\仁愛醫院調整8總整理\outputs_bin(2),(3)...
# 3  D:\中興大學\碩一上\仁愛醫院\仁愛醫院調整8總整理\outputs_bin(2),(3)...
# 2  D:\中興大學\碩一上\仁愛醫院\仁愛醫院調整8總整理\outputs_bin(2),(3)...
# 0  D:\中興大學\碩一上\仁愛醫院\仁愛醫院調整8總整理\outputs_bin(2),(3)...
# 4  D:\中興大學\碩一上\仁愛醫院\仁愛醫院調整8總整理\outputs_bin(2),(3)...
#
#                                      val_report_path  \
# 5  D:\中興大學\碩一上\仁愛醫院\仁愛醫院調整8總整理\outputs_bin(2),(3)...
# 6  D:\中興大學\碩一上\仁愛醫院\仁愛醫院調整8總整理\outputs_bin(2),(3)...
# 1  D:\中興大學\碩一上\仁愛醫院\仁愛醫院調整8總整理\outputs_bin(2),(3)...
# 3  D:\中興大學\碩一上\仁愛醫院\仁愛醫院調整8總整理\outputs_bin(2),(3)...
# 2  D:\中興大學\碩一上\仁愛醫院\仁愛醫院調整8總整理\outputs_bin(2),(3)...
# 0  D:\中興大學\碩一上\仁愛醫院\仁愛醫院調整8總整理\outputs_bin(2),(3)...
# 4  D:\中興大學\碩一上\仁愛醫院\仁愛醫院調整8總整理\outputs_bin(2),(3)...
#
#                                     test_report_path  is_best_val_macro_f1
# 5  D:\中興大學\碩一上\仁愛醫院\仁愛醫院調整8總整理\outputs_bin(2),(3)...                  True
# 6  D:\中興大學\碩一上\仁愛醫院\仁愛醫院調整8總整理\outputs_bin(2),(3)...                 False
# 1  D:\中興大學\碩一上\仁愛醫院\仁愛醫院調整8總整理\outputs_bin(2),(3)...                 False
# 3  D:\中興大學\碩一上\仁愛醫院\仁愛醫院調整8總整理\outputs_bin(2),(3)...                 False
# 2  D:\中興大學\碩一上\仁愛醫院\仁愛醫院調整8總整理\outputs_bin(2),(3)...                 False
# 0  D:\中興大學\碩一上\仁愛醫院\仁愛醫院調整8總整理\outputs_bin(2),(3)...                 False
# 4  D:\中興大學\碩一上\仁愛醫院\仁愛醫院調整8總整理\outputs_bin(2),(3)...                 False

# %%
# STEP 6 — Grad-CAM 工具

import torch
import torch.nn.functional as F
import matplotlib.pyplot as plt
import numpy as np
from pathlib import Path
import cv2

# ==========================================
# 1. 基礎設定與函式
# ==========================================

# ⚠️ 根據你訓練時的 Normalize 設定
MEAN = [0.5, 0.5, 0.5]
STD  = [0.5, 0.5, 0.5]
device = "cuda" if torch.cuda.is_available() else "cpu"

def denormalize(img_tensor):
    """反正規化：Tensor -> Numpy Image [0,1]"""
    img = img_tensor.clone().cpu().numpy()
    for c in range(3):
        img[c] = img[c] * STD[c] + MEAN[c]
    img = np.clip(img, 0, 1)
    img = np.transpose(img, (1, 2, 0))
    return img

class GradCAM:
    def __init__(self, model, target_layer):
        self.model = model
        self.target_layer = target_layer
        self.activations = None
        self.gradients = None
        self._register_hooks()

    def _register_hooks(self):
        def forward_hook(module, inp, out):
            self.activations = out.detach()
        def backward_hook(module, grad_in, grad_out):
            self.gradients = grad_out[0].detach()
        self.target_layer.register_forward_hook(forward_hook)
        self.target_layer.register_backward_hook(backward_hook)

    def __call__(self, x, class_idx=None):
        self.model.zero_grad()
        out = self.model(x)
        if class_idx is None:
            class_idx = out.argmax(dim=1).item()
        score = out[0, class_idx]
        score.backward()
        
        acts = self.activations
        grads = self.gradients
        weights = grads.mean(dim=(2, 3))[0]
        
        gcam = torch.zeros(acts.shape[2:], dtype=torch.float32).to(acts.device)
        for i, w in enumerate(weights):
            gcam += w * acts[0, i, :, :]
            
        gcam = F.relu(gcam)
        gcam -= gcam.min()
        if gcam.max() > 0:
            gcam /= gcam.max()
        return gcam.detach().cpu().numpy()

def get_target_layer(model, model_name: str):
    model_name = model_name.lower()
    if model_name in ["convnext_tiny", "convnext_small", "convnext_base"]:
        return model.features[-1]
    elif model_name == "resnet50":
        return model.layer4
    elif model_name in ["densenet121", "densenet169"]:
        # DenseNet 的 features 包含所有 DenseBlock，通常取最後一層輸出
        return model.features
    elif model_name in ["efficientnet_b0", "efficientnet_b1"]:
        return model.features[-1]
    else:
        raise ValueError(f"Unknown model name: {model_name}")

# %%
# ==========================================
# 2. 🔥 關鍵：載入最佳模型 (避免用到最後訓練的那一個)
# ==========================================

# 從上一部 Summary 找出最佳模型名稱 (或是你自己手動指定，例如 "densenet121")
# 假設 best_model 變數還在記憶體中，如果不在，請手動改成字串，如 BEST_MODEL_NAME = "densenet121"
try:
    BEST_MODEL_NAME = best_model 
except NameError:
    BEST_MODEL_NAME = "densenet121"  # ⚠️ 如果報錯，請手動改成你剛剛跑出來的第一名模型名稱

print(f"🔥 正在載入最佳模型：{BEST_MODEL_NAME} ...")

# 重新建立架構
model_vis = create_model(BEST_MODEL_NAME, num_classes=2).to(device)

# 載入權重 (從 outputs/_best_model 讀取)
best_ckpt_path = PROJ / "outputs_bin(2),(3)" / "_best_model" / f"best_{BEST_MODEL_NAME}.pth"
if best_ckpt_path.exists():
    model_vis.load_state_dict(torch.load(best_ckpt_path, map_location=device))
    print(f"✅ 成功載入權重：{best_ckpt_path}")
else:
    print(f"❌ 找不到權重檔：{best_ckpt_path}，請檢查路徑！")
# Out:
# 🔥 正在載入最佳模型：densenet121 ...
# ✅ 成功載入權重：D:\中興大學\碩一上\仁愛醫院\仁愛醫院調整8總整理\outputs_bin(2),(3)\_best_model\best_densenet121.pth

# %%
# ==========================================
# 3. 執行 Grad-CAM 並存檔
# ==========================================

target_layer = get_target_layer(model_vis, BEST_MODEL_NAME)
gcam = GradCAM(model_vis, target_layer)

# 動態設定資料夾名稱
GCAM_DIR = PROJ / f"m3_gradcam_{BEST_MODEL_NAME}"
GCAM_DIR.mkdir(exist_ok=True, parents=True)
print("📂 Grad-CAM 圖片將存到：", GCAM_DIR)

n_show = 45  # 設定要輸出的張數
shown = 0

# 定義顯示用的類別名稱 (對應 0 和 1)
class_map = {0: "Stage 2", 1: "Stage 3"}

model_vis.eval()

# 這裡不加 no_grad，因為 Grad-CAM 需要 backward 算梯度
for imgs, labels in test_loader:
    imgs = imgs.to(device)
    labels = labels.to(device)

    batch_size = imgs.size(0)
    for i in range(batch_size):
        if shown >= n_show:
            break

        img = imgs[i:i+1]
        label_idx = labels[i].item()
        label_str = class_map[label_idx] # 轉成文字 Stage 1-3 或 Stage 4

        # Forward
        model_vis.zero_grad()
        out = model_vis(img)
        pred_idx = out.argmax(1).item()
        pred_str = class_map[pred_idx]

        # 計算 Grad-CAM
        gcam_map = gcam(img, class_idx=pred_idx)

        # 畫圖
        img_np = denormalize(img[0])
        h, w, _ = img_np.shape
        gcam_resized = cv2.resize(gcam_map, (w, h))
        heatmap = cv2.applyColorMap(np.uint8(255 * gcam_resized), cv2.COLORMAP_JET)
        heatmap = cv2.cvtColor(heatmap, cv2.COLOR_BGR2RGB) / 255.0
        overlay = np.clip(0.4 * heatmap + 0.6 * img_np, 0, 1)

        fig, axes = plt.subplots(1, 3, figsize=(12, 4))
        
        axes[0].imshow(img_np)
        axes[0].set_title(f"Original\nGT: {label_str}")
        axes[0].axis("off")

        axes[1].imshow(gcam_resized, cmap="jet")
        axes[1].set_title(f"Grad-CAM\nPred: {pred_str}")
        axes[1].axis("off")

        axes[2].imshow(overlay)
        axes[2].set_title("Overlay")
        axes[2].axis("off")

        # 檔名加入 GT 和 Pred 資訊方便篩選
        file_name = f"m3_test_{shown+1}_GT-{label_idx}_Pred-{pred_idx}.png"
        save_path = GCAM_DIR / file_name
        plt.savefig(save_path, dpi=150, bbox_inches='tight')
        plt.close(fig) # 關閉圖片釋放記憶體，避免大量迴圈時爆掉

        if shown % 5 == 0:
            print(f"Saved: {file_name}")
            
        shown += 1

    if shown >= n_show:
        break

print(f"\n✅ 全部完成！請到資料夾查看圖片：\n{GCAM_DIR}")
# Out:
# 📂 Grad-CAM 圖片將存到： D:\中興大學\碩一上\仁愛醫院\仁愛醫院調整8總整理\m3_gradcam_densenet121
# c:\Users\USER\anaconda3\envs\unet_labeling\Lib\site-packages\torch\nn\modules\module.py:1868: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# Saved: m3_test_1_GT-0_Pred-0.png
# Saved: m3_test_6_GT-0_Pred-1.png
# Saved: m3_test_11_GT-0_Pred-0.png
# Saved: m3_test_16_GT-0_Pred-0.png
# Saved: m3_test_21_GT-1_Pred-1.png
# Saved: m3_test_26_GT-1_Pred-1.png
#
# ✅ 全部完成！請到資料夾查看圖片：
# D:\中興大學\碩一上\仁愛醫院\仁愛醫院調整8總整理\m3_gradcam_densenet121
